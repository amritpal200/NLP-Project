# %%
import json
import os
import pprint
from langdetect import detect, DetectorFactory
import nltk
import spacy
import re
from tqdm import tqdm
import numpy as np

data = json.load(open(os.path.join("data", "training_data.json")))

# %%
data[0]["data"]["text"][:1000]
# Out:
# " nº historia clinica: ** *** *** nºepisodi: ******** sexe: home data de naixement: 16.05.1936 edat: 82 anys procedencia cex mateix hosp servei urologia data d'ingres 24.07.2018 data d'alta 25.07.2018 08:54:04 ates per ***************, *****; ****************, ****** informe d'alta d'hospitalitzacio motiu d'ingres paciente que ingresa de forma programada para realizacion de uretrotomia interna . antecedents alergia a penicilina y cloramfenicol . no habitos toxicos. antecedentes medicos: bloqueo auriculoventricular de primer grado hipertension arterial. diverticulosis extensa insuficiencia renal cronica colelitiasis antecedentes quirurgicos: exeresis de lesiones cutaneas con anestesia local protesis total de cadera cordectomia herniorrafia inguinal proces actual varon de 81a que a raiz de episodio de hematuria macroscopica se realiza cistoscopia que es negativa para lesiones malignas pero se objetiva estenosis de uretra . se intentan dilataciones progresivas en el gabinete de urologia si"

# %%
# python -m spacy download es_core_news_sm
# python -m spacy download ca_core_news_sm
nlp_es = spacy.load("es_core_news_sm")
nlp_ca = spacy.load("ca_core_news_sm")

# %%
DetectorFactory.seed = 0

def detect_lang(text: str):
	try:
		lang = detect(text)
		if lang not in ["es", "ca"]:
			return "es"
		return lang
	except:
		return "es"

# %%
def sent_tokenize(text: str):
	sents = nltk.sent_tokenize(text, language="spanish") # assuming for catalan will be similar
	text_cpy = text
	spans = []
	l = 0
	for sent in sents:
		pos = text_cpy.find(sent)
		span = (pos, pos + len(sent))
		span = (0, span[1]) # keep from start in case space was removed during tokenization
		sent = text_cpy[span[0]:span[1]]
		text_cpy = text_cpy[span[1]:]
		span = (l + span[0], l + span[1])
		spans.append({"text":sent, "span":span})
		l = span[1]
	if text_cpy:
		last_sent, last_span = spans[-1]["text"], spans[-1]["span"]
		last_span = (last_span[0], len(text))
		last_sent = last_sent + text_cpy
		spans[-1] = {"text":last_sent, "span":last_span}
	return spans

sents = []
for d in tqdm(data):
	text = d["data"]["text"]
	spans = sent_tokenize(text)
	for i, s in enumerate(spans):
		sent, span = s["text"], s["span"]
		assert sent == text[span[0]:span[1]]
		lang = detect_lang(sent)
		spans[i]["lang"] = lang
	sents.append(spans)
# Out:
# 100%|██████████| 254/254 [01:08<00:00,  3.68it/s]

# %%
sents[0][1]
# Out:
# {'text': ' antecedents alergia a penicilina y cloramfenicol .',
#  'span': (397, 448),
#  'lang': 'ca'}

# %%
tokens = []
for d in tqdm(sents):
	d_tokens = []
	for sent in d:
		text = sent["text"]
		span = sent["span"]
		lang = sent["lang"]
		if lang == "es":
			doc = nlp_es.tokenizer(text)
		else:
			doc = nlp_ca.tokenizer(text)
		_tokens = []
		spans = []
		for token in doc:
			if token.text != "*": _tokens.append(token.text)
			spans.append([span[0] + token.idx, span[0] + token.idx + len(token.text)])
		sent_tokens = {"tokens": np.array(_tokens), "spans": np.array(spans), "lang": lang}
		d_tokens.append(sent_tokens)
	tokens.append(d_tokens)
# Out:
# 100%|██████████| 254/254 [00:02<00:00, 90.58it/s]

# %%
tokens[0]
# Out:
# [{'tokens': array([' ', 'nº', 'historia', 'clinica', ':', 'nºepisodi', ':', 'sexe',
#          ':', 'home', 'data', 'de', 'naixement', ':', '16.05.1936', 'edat',
#          ':', '82', 'anys', 'procedencia', 'cex', 'mateix', 'hosp',
#          'servei', 'urologia', 'data', "d'", 'ingres', '24.07.2018', 'data',
#          "d'", 'alta', '25.07.2018', '08:54:04', 'ates', 'per', ',', ';',
#          ',', 'informe', "d'", 'alta', "d'", 'hospitalitzacio', 'motiu',
#          "d'", 'ingres', 'paciente', 'que', 'ingresa', 'de', 'forma',
#          'programada', 'para', 'realizacion', 'de', 'uretrotomia',
#          'interna', '.'], dtype='<U15'),
#   'spans': array([[  0,   1],
#          [  1,   3],
#          [  4,  12],
#          [ 13,  20],
#          [ 20,  21],
#          [ 22,  23],
#          [ 23,  24],
#          [ 25,  26],
#          [ 26,  27],
#          [ 27,  28],
#          [ 29,  30],
#          [ 30,  31],
#          [ 31,  32],
#          [ 33,  42],
#          [ 42,  43],
#          [ 44,  45],
#          [ 45,  46],
#          [ 46,  47],
#          [ 47,  48],
#          [ 48,  49],
#          [ 49,  50],
#          [ 50,  51],
#          [ 51,  52],
#          [ 53,  57],
#          [ 57,  58],
#          [ 59,  63],
#          [ 64,  68],
#          [ 69,  71],
#          [ 72,  81],
#          [ 81,  82],
#          [ 83,  93],
#          [ 94,  98],
#          [ 98,  99],
#          [100, 102],
#          [103, 107],
#          [108, 119],
#          [120, 123],
#          [124, 130],
#          [131, 135],
#          [136, 142],
#          [143, 151],
#          [152, 156],
#          [157, 159],
#          [159, 165],
#          [166, 176],
#          [177, 181],
#          [182, 184],
#          [184, 188],
#          [189, 199],
#          [200, 208],
#          [209, 213],
#          [214, 217],
#          [218, 219],
#          [219, 220],
#          [220, 221],
#          [221, 222],
#          [222, 223],
#          [223, 224],
#          [224, 225],
#          [225, 226],
#          [226, 227],
#          [227, 228],
#          [228, 229],
#          [229, 230],
#          [230, 231],
#          [231, 232],
#          [232, 233],
#          [233, 234],
#          [235, 236],
#          [236, 237],
#          [237, 238],
#          [238, 239],
#          [239, 240],
#          [240, 241],
#          [242, 243],
#          [243, 244],
#          [244, 245],
#          [245, 246],
#          [246, 247],
#          [247, 248],
#          [248, 249],
#          [249, 250],
#          [250, 251],
#          [251, 252],
#          [252, 253],
#          [253, 254],
#          [254, 255],
#          [255, 256],
#          [256, 257],
#          [257, 258],
#          [258, 259],
#          [260, 261],
#          [261, 262],
#          [262, 263],
#          [263, 264],
#          [264, 265],
#          [265, 266],
#          [267, 274],
#          [275, 277],
#          [277, 281],
#          [282, 284],
#          [284, 299],
#          [300, 305],
#          [306, 308],
#          [308, 314],
#          [315, 323],
#          [324, 327],
#          [328, 335],
#          [336, 338],
#          [339, 344],
#          [345, 355],
#          [356, 360],
#          [361, 372],
#          [373, 375],
#          [376, 387],
#          [388, 395],
#          [396, 397]]),
#   'lang': 'ca'},
#  {'tokens': array([' ', 'antecedents', 'alergia', 'a', 'penicilina', 'y',
#          'cloramfenicol', '.'], dtype='<U13'),
#   'spans': array([[397, 398],
#          [398, 409],
#          [410, 417],
#          [418, 419],
#          [420, 430],
#          [431, 432],
#          [433, 446],
#          [447, 448]]),
#   'lang': 'ca'},
#  {'tokens': array([' ', 'no', 'habitos', 'toxicos', '.'], dtype='<U7'),
#   'spans': array([[448, 449],
#          [449, 451],
#          [452, 459],
#          [460, 467],
#          [467, 468]]),
#   'lang': 'es'},
#  {'tokens': array([' ', 'antecedentes', 'medicos', ':', 'bloqueo',
#          'auriculoventricular', 'de', 'primer', 'grado', 'hipertension',
#          'arterial', '.'], dtype='<U19'),
#   'spans': array([[468, 469],
#          [469, 481],
#          [482, 489],
#          [489, 490],
#          [491, 498],
#          [499, 518],
#          [519, 521],
#          [522, 528],
#          [529, 534],
#          [535, 547],
#          [548, 556],
#          [556, 557]]),
#   'lang': 'es'},
#  {'tokens': array([' ', 'diverticulosis', 'extensa', 'insuficiencia', 'renal',
#          'cronica', 'colelitiasis', 'antecedentes', 'quirurgicos', ':',
#          'exeresis', 'de', 'lesiones', 'cutaneas', 'con', 'anestesia',
#          'local', 'protesis', 'total', 'de', 'cadera', 'cordectomia',
#          'herniorrafia', 'inguinal', 'proces', 'actual', 'varon', 'de',
#          '81a', 'que', 'a', 'raiz', 'de', 'episodio', 'de', 'hematuria',
#          'macroscopica', 'se', 'realiza', 'cistoscopia', 'que', 'es',
#          'negativa', 'para', 'lesiones', 'malignas', 'pero', 'se',
#          'objetiva', 'estenosis', 'de', 'uretra', '.'], dtype='<U14'),
#   'spans': array([[557, 558],
#          [558, 572],
#          [573, 580],
#          [581, 594],
#          [595, 600],
#          [601, 608],
#          [609, 621],
#          [622, 634],
#          [635, 646],
#          [646, 647],
#          [648, 656],
#          [657, 659],
#          [660, 668],
#          [669, 677],
#          [678, 681],
#          [682, 691],
#          [692, 697],
#          [698, 706],
#          [707, 712],
#          [713, 715],
#          [716, 722],
#          [723, 734],
#          [735, 747],
#          [748, 756],
#          [757, 763],
#          [764, 770],
#          [771, 776],
#          [777, 779],
#          [780, 783],
#          [784, 787],
#          [788, 789],
#          [790, 794],
#          [795, 797],
#          [798, 806],
#          [807, 809],
#          [810, 819],
#          [820, 832],
#          [833, 835],
#          [836, 843],
#          [844, 855],
#          [856, 859],
#          [860, 862],
#          [863, 871],
#          [872, 876],
#          [877, 885],
#          [886, 894],
#          [895, 899],
#          [900, 902],
#          [903, 911],
#          [912, 921],
#          [922, 924],
#          [925, 931],
#          [932, 933]]),
#   'lang': 'es'},
#  {'tokens': array([' ', 'se', 'intentan', 'dilataciones', 'progresivas', 'en', 'el',
#          'gabinete', 'de', 'urologia', 'sin', 'exito', '.'], dtype='<U12'),
#   'spans': array([[ 933,  934],
#          [ 934,  936],
#          [ 937,  945],
#          [ 946,  958],
#          [ 959,  970],
#          [ 971,  973],
#          [ 974,  976],
#          [ 977,  985],
#          [ 986,  988],
#          [ 989,  997],
#          [ 998, 1001],
#          [1002, 1007],
#          [1007, 1008]]),
#   'lang': 'es'},
#  {'tokens': array([' ', 'se', 'solicita', 'estudio', 'de', 'imagen', 'que',
#          'confirma', 'la', 'existencia', 'de', 'estenosis', 'a', 'nivel',
#          'd', 'uretra', 'bulbar', 'por', 'lo', 'que', 'se', 'indica',
#          'uretrtomia', 'interna', '.'], dtype='<U10'),
#   'spans': array([[1008, 1009],
#          [1009, 1011],
#          [1012, 1020],
#          [1021, 1028],
#          [1029, 1031],
#          [1032, 1038],
#          [1039, 1042],
#          [1043, 1051],
#          [1052, 1054],
#          [1055, 1065],
#          [1066, 1068],
#          [1069, 1078],
#          [1079, 1080],
#          [1081, 1086],
#          [1087, 1088],
#          [1089, 1095],
#          [1096, 1102],
#          [1103, 1106],
#          [1107, 1109],
#          [1110, 1113],
#          [1114, 1116],
#          [1117, 1123],
#          [1124, 1134],
#          [1135, 1142],
#          [1142, 1143]]),
#   'lang': 'es'},
#  {'tokens': array([' ', 'exploracio', 'complementaria', 'uretrocistografia',
#          'retrograda', '+', 'cums', '(', '11/2017', '):', 'la',
#          'uretrografia', 'retrograda', 'muestra', 'una', 'uretra',
#          'anterior', 'con', 'dos', 'estenosis', 'focales', 'a', 'nivel',
#          'de', 'uretra', 'peneana', 'y', 'bulbar', ',', 'aunque', 'se',
#          'observa', 'paso', 'de', 'contraste', 'retrogrado', 'a', 'vejiga',
#          '.'], dtype='<U17'),
#   'spans': array([[1143, 1144],
#          [1144, 1154],
#          [1155, 1169],
#          [1170, 1187],
#          [1188, 1198],
#          [1199, 1200],
#          [1201, 1205],
#          [1206, 1207],
#          [1207, 1214],
#          [1214, 1216],
#          [1217, 1219],
#          [1220, 1232],
#          [1233, 1243],
#          [1244, 1251],
#          [1252, 1255],
#          [1256, 1262],
#          [1263, 1271],
#          [1272, 1275],
#          [1276, 1279],
#          [1280, 1289],
#          [1290, 1297],
#          [1298, 1299],
#          [1300, 1305],
#          [1306, 1308],
#          [1309, 1315],
#          [1316, 1323],
#          [1324, 1325],
#          [1326, 1332],
#          [1332, 1333],
#          [1334, 1340],
#          [1341, 1343],
#          [1344, 1351],
#          [1352, 1356],
#          [1357, 1359],
#          [1360, 1369],
#          [1370, 1380],
#          [1381, 1382],
#          [1383, 1389],
#          [1389, 1390]]),
#   'lang': 'es'},
#  {'tokens': array([' ', 'vejiga', 'de', 'correcta', 'capacidad', '(', '250', 'cc',
#          'de', 'contraste', ')', ',', 'de', 'paredes', 'trabeculadas', 'y',
#          'con', 'diverticulos', ',', 'el', 'mayor', 'de', 'ellos', 'en',
#          'cara', 'posterolateral', 'izquierda', ',', 'sin', 'observarse',
#          'defectos', 'de', 'replecion', '.'], dtype='<U14'),
#   'spans': array([[1390, 1391],
#          [1391, 1397],
#          [1398, 1400],
#          [1401, 1409],
#          [1410, 1419],
#          [1420, 1421],
#          [1421, 1424],
#          [1425, 1427],
#          [1428, 1430],
#          [1431, 1440],
#          [1440, 1441],
#          [1441, 1442],
#          [1443, 1445],
#          [1446, 1453],
#          [1454, 1466],
#          [1467, 1468],
#          [1469, 1472],
#          [1473, 1485],
#          [1485, 1486],
#          [1487, 1489],
#          [1490, 1495],
#          [1496, 1498],
#          [1499, 1504],
#          [1505, 1507],
#          [1508, 1512],
#          [1513, 1527],
#          [1528, 1537],
#          [1537, 1538],
#          [1539, 1542],
#          [1543, 1553],
#          [1554, 1562],
#          [1563, 1565],
#          [1566, 1575],
#          [1575, 1576]]),
#   'lang': 'es'},
#  {'tokens': array([' ', 'la', 'uretrografia', 'miccional', 'muestra', 'una', 'uretra',
#          'prostatica', 'dilatada', ',', 'sin', 'claras', 'estenosis',
#          'focales', 'confirmandose', 'la', 'existencia', 'de', 'las', 'dos',
#          'estenosis', 'de', 'uretra', 'anterior', 'descritas',
#          'previamente', '.'], dtype='<U13'),
#   'spans': array([[1576, 1577],
#          [1577, 1579],
#          [1580, 1592],
#          [1593, 1602],
#          [1603, 1610],
#          [1611, 1614],
#          [1615, 1621],
#          [1622, 1632],
#          [1633, 1641],
#          [1641, 1642],
#          [1643, 1646],
#          [1647, 1653],
#          [1654, 1663],
#          [1664, 1671],
#          [1672, 1685],
#          [1686, 1688],
#          [1689, 1699],
#          [1700, 1702],
#          [1703, 1706],
#          [1707, 1710],
#          [1711, 1720],
#          [1721, 1723],
#          [1724, 1730],
#          [1731, 1739],
#          [1740, 1749],
#          [1750, 1761],
#          [1761, 1762]]),
#   'lang': 'es'},
#  {'tokens': array([' ', 'moderado', 'residuo', 'postmiccional', 'en', 'vejiga', 'asi',
#          'como', 'en', 'el', 'interior', 'del', 'diverticulo',
#          'posterolateral', 'izquierdo', 'descrito', '.'], dtype='<U14'),
#   'spans': array([[1762, 1763],
#          [1763, 1771],
#          [1772, 1779],
#          [1780, 1793],
#          [1794, 1796],
#          [1797, 1803],
#          [1804, 1807],
#          [1808, 1812],
#          [1813, 1815],
#          [1816, 1818],
#          [1819, 1827],
#          [1828, 1831],
#          [1832, 1843],
#          [1844, 1858],
#          [1859, 1868],
#          [1869, 1877],
#          [1877, 1878]]),
#   'lang': 'es'},
#  {'tokens': array([' ', 'uretroscopia', '(', '10/2017', ')', 'falsa', 'via', 'a',
#          'nivel', 'de', 'uretra', 'peneana', ',', 'siguiendo', 'la',
#          'uretra', 'se', 'detecta', 'gran', 'estenosis', 'que', 'no',
#          'permite', 'el', 'paso', 'de', 'una', 'guia', '.'], dtype='<U12'),
#   'spans': array([[1878, 1879],
#          [1879, 1891],
#          [1892, 1893],
#          [1893, 1900],
#          [1900, 1901],
#          [1902, 1907],
#          [1908, 1911],
#          [1912, 1913],
#          [1914, 1919],
#          [1920, 1922],
#          [1923, 1929],
#          [1930, 1937],
#          [1937, 1938],
#          [1939, 1948],
#          [1949, 1951],
#          [1952, 1958],
#          [1959, 1961],
#          [1962, 1969],
#          [1970, 1974],
#          [1975, 1984],
#          [1985, 1988],
#          [1989, 1991],
#          [1992, 1999],
#          [2000, 2002],
#          [2003, 2007],
#          [2008, 2010],
#          [2011, 2014],
#          [2015, 2019],
#          [2019, 2020]]),
#   'lang': 'es'},
#  {'tokens': array([' ', 'nhc', '(', ')', 'age-v-uro', '1/2', 'lopd', 'evolucio',
#          'clinica', 'el', '24', 'de', 'julio', 'de', '2018', 'con', 'el',
#          'consentimiento', 'informado', 'del', 'paciente', 'y', 'sin',
#          'contraindicacion', 'preoperatoria', 'se', 'realiza',
#          'uretrotomia', 'interna', 'sin', 'incidencias', '.'], dtype='<U16'),
#   'spans': array([[2020, 2021],
#          [2021, 2024],
#          [2025, 2026],
#          [2026, 2027],
#          [2028, 2029],
#          [2029, 2030],
#          [2030, 2031],
#          [2032, 2033],
#          [2033, 2034],
#          [2034, 2035],
#          [2036, 2037],
#          [2037, 2038],
#          [2038, 2039],
#          [2039, 2040],
#          [2040, 2041],
#          [2041, 2042],
#          [2042, 2043],
#          [2043, 2044],
#          [2044, 2045],
#          [2045, 2046],
#          [2047, 2056],
#          [2057, 2060],
#          [2061, 2065],
#          [2066, 2074],
#          [2075, 2082],
#          [2083, 2085],
#          [2086, 2088],
#          [2089, 2091],
#          [2092, 2097],
#          [2098, 2100],
#          [2101, 2105],
#          [2106, 2109],
#          [2110, 2112],
#          [2113, 2127],
#          [2128, 2137],
#          [2138, 2141],
#          [2142, 2150],
#          [2151, 2152],
#          [2153, 2156],
#          [2157, 2173],
#          [2174, 2187],
#          [2188, 2190],
#          [2191, 2198],
#          [2199, 2210],
#          [2211, 2218],
#          [2219, 2222],
#          [2223, 2234],
#          [2234, 2235]]),
#   'lang': 'es'},
#  {'tokens': array([' ', 'tras', 'el', 'procedimiento', 'el', 'paciente', 'es',
#          'trasladado', 'a', 'la', 'planta', 'de', 'hospitalizacion',
#          'siendo', 'portador', 'de', 'lavado', 'vesical', 'continuo', '.'],
#         dtype='<U15'),
#   'spans': array([[2235, 2236],
#          [2236, 2240],
#          [2241, 2243],
#          [2244, 2257],
#          [2258, 2260],
#          [2261, 2269],
#          [2270, 2272],
#          [2273, 2283],
#          [2284, 2285],
#          [2286, 2288],
#          [2289, 2295],
#          [2296, 2298],
#          [2299, 2314],
#          [2315, 2321],
#          [2322, 2330],
#          [2331, 2333],
#          [2334, 2340],
#          [2341, 2348],
#          [2349, 2357],
#          [2357, 2358]]),
#   'lang': 'es'},
#  {'tokens': array([' ', 'posteriormente', 'se', 'mantiene', 'en', 'buen', 'estado',
#          'general', ',', 'afebril', ',', 'hemodinamicamente', 'estable',
#          'y', 'con', 'buen', 'control', 'del', 'dolor', '.'], dtype='<U17'),
#   'spans': array([[2358, 2359],
#          [2359, 2373],
#          [2374, 2376],
#          [2377, 2385],
#          [2386, 2388],
#          [2389, 2393],
#          [2394, 2400],
#          [2401, 2408],
#          [2408, 2409],
#          [2410, 2417],
#          [2417, 2418],
#          [2419, 2436],
#          [2437, 2444],
#          [2445, 2446],
#          [2447, 2450],
#          [2451, 2455],
#          [2456, 2463],
#          [2464, 2467],
#          [2468, 2473],
#          [2473, 2474]]),
#   'lang': 'es'},
#  {'tokens': array([' ', 'aclarado', 'progresivo', 'de', 'la', 'orina', 'con', 'los',
#          'lavados', 'vesicales', 'continuos', ',', 'que', 'permiten', 'su',
#          'retirada', ',', 'conserva', 'correcta', 'diuresis', '.'],
#         dtype='<U10'),
#   'spans': array([[2474, 2475],
#          [2475, 2483],
#          [2484, 2494],
#          [2495, 2497],
#          [2498, 2500],
#          [2501, 2506],
#          [2507, 2510],
#          [2511, 2514],
#          [2515, 2522],
#          [2523, 2532],
#          [2533, 2542],
#          [2542, 2543],
#          [2544, 2547],
#          [2548, 2556],
#          [2557, 2559],
#          [2560, 2568],
#          [2568, 2569],
#          [2570, 2578],
#          [2579, 2587],
#          [2588, 2596],
#          [2596, 2597]]),
#   'lang': 'es'},
#  {'tokens': array([' ', 'tolerancia', 'correcta', 'a', 'dieta', 'oral', '.'],
#         dtype='<U10'),
#   'spans': array([[2597, 2598],
#          [2598, 2608],
#          [2609, 2617],
#          [2618, 2619],
#          [2620, 2625],
#          [2626, 2630],
#          [2630, 2631]]),
#   'lang': 'es'},
#  {'tokens': array([' ', 'dada', 'la', 'buena', 'evolucion', 'se', 'decide', 'alta',
#          'domiciliaria', 'siendo', 'portador', 'de', 'sonda', 'vesical',
#          '.'], dtype='<U12'),
#   'spans': array([[2631, 2632],
#          [2632, 2636],
#          [2637, 2639],
#          [2640, 2645],
#          [2646, 2655],
#          [2656, 2658],
#          [2659, 2665],
#          [2666, 2670],
#          [2671, 2683],
#          [2684, 2690],
#          [2691, 2699],
#          [2700, 2702],
#          [2703, 2708],
#          [2709, 2716],
#          [2716, 2717]]),
#   'lang': 'es'},
#  {'tokens': array([' ', 'orientacio', 'diagnostica', 'n40.0', 'hiperplasia',
#          'prostatica', 'benigna', 'sense', 'simptomes', 'en', 'les', 'vies',
#          'urinaries', 'inferiors', 'procediments', '04.81', 'injeccio',
#          'en', 'el', 'nervi', 'periferic', "d'", 'anestesic', 'per', 'a',
#          'analgesia', '58.0', 'uretrotomia', '.'], dtype='<U12'),
#   'spans': array([[2717, 2718],
#          [2718, 2728],
#          [2729, 2740],
#          [2741, 2746],
#          [2747, 2758],
#          [2759, 2769],
#          [2770, 2777],
#          [2778, 2783],
#          [2784, 2793],
#          [2794, 2796],
#          [2797, 2800],
#          [2801, 2805],
#          [2806, 2815],
#          [2816, 2825],
#          [2826, 2838],
#          [2839, 2844],
#          [2845, 2853],
#          [2854, 2856],
#          [2857, 2859],
#          [2860, 2865],
#          [2866, 2875],
#          [2876, 2878],
#          [2878, 2887],
#          [2888, 2891],
#          [2892, 2893],
#          [2894, 2903],
#          [2904, 2908],
#          [2909, 2920],
#          [2920, 2921]]),
#   'lang': 'ca'},
#  {'tokens': array([' ', 'excisio', 'de', 'septe', 'uretral', ',', 'uretrostomia',
#          'perineal', ',', 'extraccio', 'de', 'calcul', 'uretral', 'per',
#          'incisio', 'sonda', 'vesical', 'profilaxis', 'antibiotica', ',',
#          'antilucerosa', 'y', 'antitrombotica', 'tractament', 'i',
#          'recomanacions', 'a', "l'alta", '-abundante', 'ingesta', 'de',
#          'liquidos', 'entorno', 'a', 'dos', 'litros', 'y', 'medio', 'de',
#          'agua', 'al', 'dia', '.'], dtype='<U14'),
#   'spans': array([[2921, 2922],
#          [2922, 2929],
#          [2930, 2932],
#          [2933, 2938],
#          [2939, 2946],
#          [2946, 2947],
#          [2948, 2960],
#          [2961, 2969],
#          [2969, 2970],
#          [2971, 2980],
#          [2981, 2983],
#          [2984, 2990],
#          [2991, 2998],
#          [2999, 3002],
#          [3003, 3010],
#          [3011, 3016],
#          [3017, 3024],
#          [3025, 3035],
#          [3036, 3047],
#          [3047, 3048],
#          [3049, 3061],
#          [3062, 3063],
#          [3064, 3078],
#          [3079, 3089],
#          [3090, 3091],
#          [3092, 3105],
#          [3106, 3107],
#          [3108, 3114],
#          [3115, 3125],
#          [3126, 3133],
#          [3134, 3136],
#          [3137, 3145],
#          [3146, 3153],
#          [3154, 3155],
#          [3156, 3159],
#          [3160, 3166],
#          [3167, 3168],
#          [3169, 3174],
#          [3175, 3177],
#          [3178, 3182],
#          [3183, 3185],
#          [3186, 3189],
#          [3189, 3190]]),
#   'lang': 'es'},
#  {'tokens': array([' ', '-puede', 'orinar', 'con', 'restos', 'de', 'sangre',
#          'durante', 'las', 'proximas', 'semanas', '.'], dtype='<U8'),
#   'spans': array([[3190, 3191],
#          [3191, 3197],
#          [3198, 3204],
#          [3205, 3208],
#          [3209, 3215],
#          [3216, 3218],
#          [3219, 3225],
#          [3226, 3233],
#          [3234, 3237],
#          [3238, 3246],
#          [3247, 3254],
#          [3254, 3255]]),
#   'lang': 'es'},
#  {'tokens': array([' ', '-es', 'normal', 'que', 'sienta', 'escozor', 'al', 'orinar',
#          'y', 'que', 'tenga', 'algun', 'escape', 'de', 'orina', 'y',
#          'urgencia', 'miccional', 'al', 'retirar', 'la', 'sonda', 'vesical',
#          '.'], dtype='<U9'),
#   'spans': array([[3255, 3256],
#          [3256, 3259],
#          [3260, 3266],
#          [3267, 3270],
#          [3271, 3277],
#          [3278, 3285],
#          [3286, 3288],
#          [3289, 3295],
#          [3296, 3297],
#          [3298, 3301],
#          [3302, 3307],
#          [3308, 3313],
#          [3314, 3320],
#          [3321, 3323],
#          [3324, 3329],
#          [3330, 3331],
#          [3332, 3340],
#          [3341, 3350],
#          [3351, 3353],
#          [3354, 3361],
#          [3362, 3364],
#          [3365, 3370],
#          [3371, 3378],
#          [3378, 3379]]),
#   'lang': 'es'},
#  {'tokens': array([' ', 'mantener', 'sonda', 'vesical', 'durante', '14', 'dias', '(',
#          'dos', 'semanas', ')', '.'], dtype='<U8'),
#   'spans': array([[3379, 3380],
#          [3380, 3388],
#          [3389, 3394],
#          [3395, 3402],
#          [3403, 3410],
#          [3411, 3413],
#          [3414, 3418],
#          [3419, 3420],
#          [3420, 3423],
#          [3424, 3431],
#          [3431, 3432],
#          [3432, 3433]]),
#   'lang': 'es'},
#  {'tokens': array([' ', 'ciprofloxacino', '500', 'mg', 'cada', '12h', 'durante',
#          'dos', 'semanas', '.'], dtype='<U14'),
#   'spans': array([[3433, 3434],
#          [3434, 3448],
#          [3449, 3452],
#          [3452, 3454],
#          [3455, 3459],
#          [3460, 3463],
#          [3464, 3471],
#          [3472, 3475],
#          [3476, 3483],
#          [3483, 3484]]),
#   'lang': 'es'},
#  {'tokens': array([' ', '-paracetamol', '1', 'g', 'cada', '8', 'horas', 'si',
#          'molestias', '.'], dtype='<U12'),
#   'spans': array([[3484, 3485],
#          [3485, 3497],
#          [3498, 3499],
#          [3500, 3501],
#          [3502, 3506],
#          [3507, 3508],
#          [3509, 3514],
#          [3515, 3517],
#          [3518, 3527],
#          [3527, 3528]]),
#   'lang': 'es'},
#  {'tokens': array([' ', '-si', 'fiebre', 'mayor', 'de', '38ºc', ',', 'empeoramiento',
#          'claro', 'del', 'estado', 'general', 'o', 'imposibilidad',
#          'miccional', 'por', 'obstruccion', 'de', 'sonda', 'vesical', 'o',
#          'despues', 'de', 'su', 'retirada', ',', 'consultar', 'con', 'el',
#          'servicio', 'de', 'urgencias', '.'], dtype='<U13'),
#   'spans': array([[3528, 3529],
#          [3529, 3532],
#          [3533, 3539],
#          [3540, 3545],
#          [3546, 3548],
#          [3549, 3553],
#          [3553, 3554],
#          [3555, 3568],
#          [3569, 3574],
#          [3575, 3578],
#          [3579, 3585],
#          [3586, 3593],
#          [3594, 3595],
#          [3596, 3609],
#          [3610, 3619],
#          [3620, 3623],
#          [3624, 3635],
#          [3636, 3638],
#          [3639, 3644],
#          [3645, 3652],
#          [3653, 3654],
#          [3655, 3662],
#          [3663, 3665],
#          [3666, 3668],
#          [3669, 3677],
#          [3677, 3678],
#          [3679, 3688],
#          [3689, 3692],
#          [3693, 3695],
#          [3696, 3704],
#          [3705, 3707],
#          [3708, 3717],
#          [3717, 3718]]),
#   'lang': 'es'},
#  {'tokens': array([' ', '-control', 'en', 'consultas', 'externas', 'de', 'urologia',
#          'segun', 'cita', 'en', 'hoja', 'adjunta', '.'], dtype='<U9'),
#   'spans': array([[3718, 3719],
#          [3719, 3727],
#          [3728, 3730],
#          [3731, 3740],
#          [3741, 3749],
#          [3750, 3752],
#          [3753, 3761],
#          [3762, 3767],
#          [3768, 3772],
#          [3773, 3775],
#          [3776, 3780],
#          [3781, 3788],
#          [3788, 3789]]),
#   'lang': 'es'},
#  {'tokens': array([' ', 'destinacio', 'a', "l'alta", ':', 'a', 'domicili', 'nhc', '(',
#          ')', 'age-v-uro', '2/2', 'lopd'], dtype='<U10'),
#   'spans': array([[3789, 3790],
#          [3790, 3800],
#          [3801, 3802],
#          [3803, 3809],
#          [3809, 3810],
#          [3811, 3812],
#          [3813, 3821],
#          [3822, 3825],
#          [3826, 3827],
#          [3827, 3828],
#          [3829, 3830],
#          [3830, 3831],
#          [3831, 3832],
#          [3833, 3834],
#          [3834, 3835],
#          [3835, 3836],
#          [3837, 3838],
#          [3838, 3839],
#          [3839, 3840],
#          [3840, 3841],
#          [3841, 3842],
#          [3842, 3843],
#          [3843, 3844],
#          [3844, 3845],
#          [3845, 3846],
#          [3846, 3847],
#          [3848, 3857],
#          [3858, 3861],
#          [3862, 3866]]),
#   'lang': 'es'}]

# %%
string = data[0]["data"]["text"]
doc = nlp_ca.tokenizer(string)
for token in doc:
	print(token.text, token.idx)
# Out:
#   0
# nº 1
# historia 4
# clinica 13
# : 20
# * 22
# * 23
# * 25
# * 26
# * 27
# * 29
# * 30
# * 31
# nºepisodi 33
# : 42
# * 44
# * 45
# * 46
# * 47
# * 48
# * 49
# * 50
# * 51
# sexe 53
# : 57
# home 59
# data 64
# de 69
# naixement 72
# : 81
# 16.05.1936 83
# edat 94
# : 98
# 82 100
# anys 103
# procedencia 108
# cex 120
# mateix 124
# hosp 131
# servei 136
# urologia 143
# data 152
# d' 157
# ingres 159
# 24.07.2018 166
# data 177
# d' 182
# alta 184
# 25.07.2018 189
# 08:54:04 200
# ates 209
# per 214
# * 218
# * 219
# * 220
# * 221
# * 222
# * 223
# * 224
# * 225
# * 226
# * 227
# * 228
# * 229
# * 230
# * 231
# * 232
# , 233
# * 235
# * 236
# * 237
# * 238
# * 239
# ; 240
# * 242
# * 243
# * 244
# * 245
# * 246
# * 247
# * 248
# * 249
# * 250
# * 251
# * 252
# * 253
# * 254
# * 255
# * 256
# * 257
# , 258
# * 260
# * 261
# * 262
# * 263
# * 264
# * 265
# informe 267
# d' 275
# alta 277
# d' 282
# hospitalitzacio 284
# motiu 300
# d' 306
# ingres 308
# paciente 315
# que 324
# ingresa 328
# de 336
# forma 339
# programada 345
# para 356
# realizacion 361
# de 373
# uretrotomia 376
# interna 388
# . 396
# antecedents 398
# alergia 410
# a 418
# penicilina 420
# y 431
# cloramfenicol 433
# . 447
# no 449
# habitos 452
# toxicos 460
# . 467
# antecedentes 469
# medicos 482
# : 489
# bloqueo 491
# auriculoventricular 499
# de 519
# primer 522
# grado 529
# hipertension 535
# arterial 548
# . 556
# diverticulosis 558
# extensa 573
# insuficiencia 581
# renal 595
# cronica 601
# colelitiasis 609
# antecedentes 622
# quirurgicos 635
# : 646
# exeresis 648
# de 657
# lesiones 660
# cutaneas 669
# con 678
# anestesia 682
# local 692
# protesis 698
# total 707
# de 713
# cadera 716
# cordectomia 723
# herniorrafia 735
# inguinal 748
# proces 757
# actual 764
# varon 771
# de 777
# 81a 780
# que 784
# a 788
# raiz 790
# de 795
# episodio 798
# de 807
# hematuria 810
# macroscopica 820
# se 833
# realiza 836
# cistoscopia 844
# que 856
# es 860
# negativa 863
# para 872
# lesiones 877
# malignas 886
# pero 895
# se 900
# objetiva 903
# estenosis 912
# de 922
# uretra 925
# . 932
# se 934
# intentan 937
# dilataciones 946
# progresivas 959
# en 971
# el 974
# gabinete 977
# de 986
# urologia 989
# sin 998
# exito 1002
# . 1007
# se 1009
# solicita 1012
# estudio 1021
# de 1029
# imagen 1032
# que 1039
# confirma 1043
# la 1052
# existencia 1055
# de 1066
# estenosis 1069
# a 1079
# nivel 1081
# d 1087
# uretra 1089
# bulbar 1096
# por 1103
# lo 1107
# que 1110
# se 1114
# indica 1117
# uretrtomia 1124
# interna 1135
# . 1142
# exploracio 1144
# complementaria 1155
# uretrocistografia 1170
# retrograda 1188
# + 1199
# cums 1201
# ( 1206
# 11/2017 1207
# ): 1214
# la 1217
# uretrografia 1220
# retrograda 1233
# muestra 1244
# una 1252
# uretra 1256
# anterior 1263
# con 1272
# dos 1276
# estenosis 1280
# focales 1290
# a 1298
# nivel 1300
# de 1306
# uretra 1309
# peneana 1316
# y 1324
# bulbar 1326
# , 1332
# aunque 1334
# se 1341
# observa 1344
# paso 1352
# de 1357
# contraste 1360
# retrogrado 1370
# a 1381
# vejiga 1383
# . 1389
# vejiga 1391
# de 1398
# correcta 1401
# capacidad 1410
# ( 1420
# 250 1421
# cc 1425
# de 1428
# contraste 1431
# ) 1440
# , 1441
# de 1443
# paredes 1446
# trabeculadas 1454
# y 1467
# con 1469
# diverticulos 1473
# , 1485
# el 1487
# mayor 1490
# de 1496
# ellos 1499
# en 1505
# cara 1508
# posterolateral 1513
# izquierda 1528
# , 1537
# sin 1539
# observarse 1543
# defectos 1554
# de 1563
# replecion 1566
# . 1575
# la 1577
# uretrografia 1580
# miccional 1593
# muestra 1603
# una 1611
# uretra 1615
# prostatica 1622
# dilatada 1633
# , 1641
# sin 1643
# claras 1647
# estenosis 1654
# focales 1664
# confirmandose 1672
# la 1686
# existencia 1689
# de 1700
# las 1703
# dos 1707
# estenosis 1711
# de 1721
# uretra 1724
# anterior 1731
# descritas 1740
# previamente 1750
# . 1761
# moderado 1763
# residuo 1772
# postmiccional 1780
# en 1794
# vejiga 1797
# asi 1804
# como 1808
# en 1813
# el 1816
# interior 1819
# d 1828
# el 1829
# diverticulo 1832
# posterolateral 1844
# izquierdo 1859
# descrito 1869
# . 1877
# uretroscopia 1879
# ( 1892
# 10/2017 1893
# ) 1900
# falsa 1902
# via 1908
# a 1912
# nivel 1914
# de 1920
# uretra 1923
# peneana 1930
# , 1937
# siguiendo 1939
# la 1949
# uretra 1952
# se 1959
# detecta 1962
# gran 1970
# estenosis 1975
# que 1985
# no 1989
# permite 1992
# el 2000
# paso 2003
# de 2008
# una 2011
# guia 2015
# . 2019
# nhc 2021
# * 2025
# * 2026
# * 2028
# * 2029
# * 2030
# * 2032
# * 2033
# * 2034
# ( 2036
# * 2037
# * 2038
# * 2039
# * 2040
# * 2041
# * 2042
# * 2043
# * 2044
# ) 2045
# age-v-uro 2047
# 1/2 2057
# lopd 2061
# evolucio 2066
# clinica 2075
# el 2083
# 24 2086
# de 2089
# julio 2092
# de 2098
# 2018 2101
# con 2106
# el 2110
# consentimiento 2113
# informado 2128
# d 2138
# el 2139
# paciente 2142
# y 2151
# sin 2153
# contraindicacion 2157
# preoperatoria 2174
# se 2188
# realiza 2191
# uretrotomia 2199
# interna 2211
# sin 2219
# incidencias 2223
# . 2234
# tras 2236
# el 2241
# procedimiento 2244
# el 2258
# paciente 2261
# es 2270
# trasladado 2273
# a 2284
# la 2286
# planta 2289
# de 2296
# hospitalizacion 2299
# siendo 2315
# portador 2322
# de 2331
# lavado 2334
# vesical 2341
# continuo 2349
# . 2357
# posteriormente 2359
# se 2374
# mantiene 2377
# en 2386
# buen 2389
# estado 2394
# general 2401
# , 2408
# afebril 2410
# , 2417
# hemodinamicamente 2419
# estable 2437
# y 2445
# con 2447
# buen 2451
# control 2456
# d 2464
# el 2465
# dolor 2468
# . 2473
# aclarado 2475
# progresivo 2484
# de 2495
# la 2498
# orina 2501
# con 2507
# los 2511
# lavados 2515
# vesicales 2523
# continuos 2533
# , 2542
# que 2544
# permiten 2548
# su 2557
# retirada 2560
# , 2568
# conserva 2570
# correcta 2579
# diuresis 2588
# . 2596
# tolerancia 2598
# correcta 2609
# a 2618
# dieta 2620
# oral 2626
# . 2630
# dada 2632
# la 2637
# buena 2640
# evolucion 2646
# se 2656
# decide 2659
# alta 2666
# domiciliaria 2671
# siendo 2684
# portador 2691
# de 2700
# sonda 2703
# vesical 2709
# . 2716
# orientacio 2718
# diagnostica 2729
# n40.0 2741
# hiperplasia 2747
# prostatica 2759
# benigna 2770
# sense 2778
# simptomes 2784
# en 2794
# les 2797
# vies 2801
# urinaries 2806
# inferiors 2816
# procediments 2826
# 04.81 2839
# injeccio 2845
# en 2854
# el 2857
# nervi 2860
# periferic 2866
# d' 2876
# anestesic 2878
# per 2888
# a 2892
# analgesia 2894
# 58.0 2904
# uretrotomia 2909
# . 2920
# excisio 2922
# de 2930
# septe 2933
# uretral 2939
# , 2946
# uretrostomia 2948
# perineal 2961
# , 2969
# extraccio 2971
# de 2981
# calcul 2984
# uretral 2991
# per 2999
# incisio 3003
# sonda 3011
# vesical 3017
# profilaxis 3025
# antibiotica 3036
# , 3047
# antilucerosa 3049
# y 3062
# antitrombotica 3064
# tractament 3079
# i 3090
# recomanacions 3092
# a 3106
# l' 3108
# alta 3110
# - 3115
# abundante 3116
# ingesta 3126
# de 3134
# liquidos 3137
# entorno 3146
# a 3154
# dos 3156
# litros 3160
# y 3167
# medio 3169
# de 3175
# agua 3178
# a 3183
# l 3184
# dia 3186
# . 3189
# - 3191
# puede 3192
# orinar 3198
# con 3205
# restos 3209
# de 3216
# sangre 3219
# durante 3226
# las 3234
# proximas 3238
# semanas 3247
# . 3254
# - 3256
# es 3257
# normal 3260
# que 3267
# sienta 3271
# escozor 3278
# a 3286
# l 3287
# orinar 3289
# y 3296
# que 3298
# tenga 3302
# algun 3308
# escape 3314
# de 3321
# orina 3324
# y 3330
# urgencia 3332
# miccional 3341
# a 3351
# l 3352
# retirar 3354
# la 3362
# sonda 3365
# vesical 3371
# . 3378
# mantener 3380
# sonda 3389
# vesical 3395
# durante 3403
# 14 3411
# dias 3414
# ( 3419
# dos 3420
# semanas 3424
# ) 3431
# . 3432
# ciprofloxacino 3434
# 500 3449
# mg 3452
# cada 3455
# 12h 3460
# durante 3464
# dos 3472
# semanas 3476
# . 3483
# - 3485
# paracetamol 3486
# 1 3498
# g 3500
# cada 3502
# 8 3507
# horas 3509
# si 3515
# molestias 3518
# . 3527
# - 3529
# si 3530
# fiebre 3533
# mayor 3540
# de 3546
# 38ºc 3549
# , 3553
# empeoramiento 3555
# claro 3569
# d 3575
# el 3576
# estado 3579
# general 3586
# o 3594
# imposibilidad 3596
# miccional 3610
# por 3620
# obstruccion 3624
# de 3636
# sonda 3639
# vesical 3645
# o 3653
# despues 3655
# de 3663
# su 3666
# retirada 3669
# , 3677
# consultar 3679
# con 3689
# el 3693
# servicio 3696
# de 3705
# urgencias 3708
# . 3717
# - 3719
# control 3720
# en 3728
# consultas 3731
# externas 3741
# de 3750
# urologia 3753
# segun 3762
# cita 3768
# en 3773
# hoja 3776
# adjunta 3781
# . 3788
# destinacio 3790
# a 3801
# l' 3803
# alta 3805
# : 3809
# a 3811
# domicili 3813
# nhc 3822
# * 3826
# * 3827
# * 3829
# * 3830
# * 3831
# * 3833
# * 3834
# * 3835
# ( 3837
# * 3838
# * 3839
# * 3840
# * 3841
# * 3842
# * 3843
# * 3844
# * 3845
# ) 3846
# age-v-uro 3848
# 2/2 3858
# lopd 3862
