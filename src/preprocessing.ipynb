# %%
import json
import os
import pprint
from langdetect import detect, DetectorFactory
import nltk
import spacy
import re
from tqdm import tqdm
import numpy as np
from unidecode import unidecode

ROOT_DIR = os.path.dirname(os.path.abspath(""))
data = json.load(open(os.path.join(ROOT_DIR, "data", "training_data.json")))

# %%
data[0]["data"]["text"][:1000]
# Out:
# " nº historia clinica: ** *** *** nºepisodi: ******** sexe: home data de naixement: 16.05.1936 edat: 82 anys procedencia cex mateix hosp servei urologia data d'ingres 24.07.2018 data d'alta 25.07.2018 08:54:04 ates per ***************, *****; ****************, ****** informe d'alta d'hospitalitzacio motiu d'ingres paciente que ingresa de forma programada para realizacion de uretrotomia interna . antecedents alergia a penicilina y cloramfenicol . no habitos toxicos. antecedentes medicos: bloqueo auriculoventricular de primer grado hipertension arterial. diverticulosis extensa insuficiencia renal cronica colelitiasis antecedentes quirurgicos: exeresis de lesiones cutaneas con anestesia local protesis total de cadera cordectomia herniorrafia inguinal proces actual varon de 81a que a raiz de episodio de hematuria macroscopica se realiza cistoscopia que es negativa para lesiones malignas pero se objetiva estenosis de uretra . se intentan dilataciones progresivas en el gabinete de urologia si"

# %%
# python -m spacy download es_core_news_sm
# python -m spacy download ca_core_news_sm
nlp_es = spacy.load("es_core_news_sm")
nlp_ca = spacy.load("ca_core_news_sm")

# %%
DetectorFactory.seed = 0

def detect_lang(text: str):
	try:
		lang = detect(text)
		if lang not in ["es", "ca"]:
			return "es"
		return lang
	except:
		return "es"

# %%
def sent_tokenize(text: str):
	sents = nltk.sent_tokenize(text, language="spanish") # assuming for catalan will be similar
	text_cpy = text
	spans = []
	l = 0
	for sent in sents:
		pos = text_cpy.find(sent)
		span = (pos, pos + len(sent))
		span = (0, span[1]) # keep from start in case space was removed during tokenization
		sent = text_cpy[span[0]:span[1]]
		text_cpy = text_cpy[span[1]:]
		span = (l + span[0], l + span[1])
		spans.append({"text":sent, "span":span})
		l = span[1]
	if text_cpy:
		last_sent, last_span = spans[-1]["text"], spans[-1]["span"]
		last_span = (last_span[0], len(text))
		last_sent = last_sent + text_cpy
		spans[-1] = {"text":last_sent, "span":last_span}
	return spans

sents = []
for d in tqdm(data):
	text = d["data"]["text"]
	spans = sent_tokenize(text)
	for i, s in enumerate(spans):
		sent, span = s["text"], s["span"]
		assert sent == text[span[0]:span[1]]
		lang = detect_lang(sent)
		spans[i]["lang"] = lang
	sents.append(spans)
# Out:
# 100%|██████████| 254/254 [01:18<00:00,  3.25it/s]

# %%
remove_asterisk = True
remove_punctuation = True
remove_spaces = True
replace_numbers = None#"<NUM>"

tokens = []
for d in tqdm(sents):
	d_tokens = []
	for sent in d:
		text = sent["text"]
		span = sent["span"]
		lang = sent["lang"]
		if lang == "es":
			doc = nlp_es.tokenizer(text)
		else:
			doc = nlp_ca.tokenizer(text)
		_tokens = []
		spans = []
		asterisk_len = 0
		asterisk_pos = 0
		for token in doc:
			word = token.text
			# handle asterisks
			if word == "*":
				if remove_asterisk: continue
				else:
					if asterisk_len == 0:
						asterisk_pos = token.idx
					asterisk_len += 1
					continue
			else:
				if asterisk_len > 0:
					_tokens.append("<HIDDEN>")
					spans.append([span[0] + asterisk_pos, span[0] + asterisk_pos + asterisk_len])
					asterisk_len = 0
			# handle numbers
			if re.fullmatch(r'(\d+[.,:/-]?)+', word) and replace_numbers:
				word = replace_numbers
			# remove punctuation
			elif remove_punctuation:
				word = re.sub(r'[^\w\s]|[ºª]', '', word)
			# remove spaces
			if remove_spaces:
				word = word.strip()
			# unidecode in case of weird characters
			word = unidecode(word)
			# append token
			if word:
				_tokens.append(word)
				spans.append([span[0] + token.idx, span[0] + token.idx + len(token.text)])
		sent_tokens = {"tokens": np.array(_tokens), "spans": np.array(spans), "lang": lang}
		d_tokens.append(sent_tokens)
	tokens.append(d_tokens)
# Out:
# 100%|██████████| 254/254 [00:03<00:00, 64.35it/s]

# %%
sents[0][0]
# Out:
# {'text': " nº historia clinica: ** *** *** nºepisodi: ******** sexe: home data de naixement: 16.05.1936 edat: 82 anys procedencia cex mateix hosp servei urologia data d'ingres 24.07.2018 data d'alta 25.07.2018 08:54:04 ates per ***************, *****; ****************, ****** informe d'alta d'hospitalitzacio motiu d'ingres paciente que ingresa de forma programada para realizacion de uretrotomia interna .",
#  'span': (0, 397),
#  'lang': 'ca'}

# %%
tokens[0]
# Out:
# [{'tokens': array(['n', 'historia', 'clinica', 'nepisodi', 'sexe', 'home', 'data',
#          'de', 'naixement', '16051936', 'edat', '82', 'anys', 'procedencia',
#          'cex', 'mateix', 'hosp', 'servei', 'urologia', 'data', 'd',
#          'ingres', '24072018', 'data', 'd', 'alta', '25072018', '085404',
#          'ates', 'per', 'informe', 'd', 'alta', 'd', 'hospitalitzacio',
#          'motiu', 'd', 'ingres', 'paciente', 'que', 'ingresa', 'de',
#          'forma', 'programada', 'para', 'realizacion', 'de', 'uretrotomia',
#          'interna'], dtype='<U15'),
#   'spans': array([[  1,   3],
#          [  4,  12],
#          [ 13,  20],
#          [ 33,  42],
#          [ 53,  57],
#          [ 59,  63],
#          [ 64,  68],
#          [ 69,  71],
#          [ 72,  81],
#          [ 83,  93],
#          [ 94,  98],
#          [100, 102],
#          [103, 107],
#          [108, 119],
#          [120, 123],
#          [124, 130],
#          [131, 135],
#          [136, 142],
#          [143, 151],
#          [152, 156],
#          [157, 159],
#          [159, 165],
#          [166, 176],
#          [177, 181],
#          [182, 184],
#          [184, 188],
#          [189, 199],
#          [200, 208],
#          [209, 213],
#          [214, 217],
#          [267, 274],
#          [275, 277],
#          [277, 281],
#          [282, 284],
#          [284, 299],
#          [300, 305],
#          [306, 308],
#          [308, 314],
#          [315, 323],
#          [324, 327],
#          [328, 335],
#          [336, 338],
#          [339, 344],
#          [345, 355],
#          [356, 360],
#          [361, 372],
#          [373, 375],
#          [376, 387],
#          [388, 395]]),
#   'lang': 'ca'},
#  {'tokens': array(['antecedents', 'alergia', 'a', 'penicilina', 'y', 'cloramfenicol'],
#         dtype='<U13'),
#   'spans': array([[398, 409],
#          [410, 417],
#          [418, 419],
#          [420, 430],
#          [431, 432],
#          [433, 446]]),
#   'lang': 'ca'},
#  {'tokens': array(['no', 'habitos', 'toxicos'], dtype='<U7'),
#   'spans': array([[449, 451],
#          [452, 459],
#          [460, 467]]),
#   'lang': 'es'},
#  {'tokens': array(['antecedentes', 'medicos', 'bloqueo', 'auriculoventricular', 'de',
#          'primer', 'grado', 'hipertension', 'arterial'], dtype='<U19'),
#   'spans': array([[469, 481],
#          [482, 489],
#          [491, 498],
#          [499, 518],
#          [519, 521],
#          [522, 528],
#          [529, 534],
#          [535, 547],
#          [548, 556]]),
#   'lang': 'es'},
#  {'tokens': array(['diverticulosis', 'extensa', 'insuficiencia', 'renal', 'cronica',
#          'colelitiasis', 'antecedentes', 'quirurgicos', 'exeresis', 'de',
#          'lesiones', 'cutaneas', 'con', 'anestesia', 'local', 'protesis',
#          'total', 'de', 'cadera', 'cordectomia', 'herniorrafia', 'inguinal',
#          'proces', 'actual', 'varon', 'de', '81a', 'que', 'a', 'raiz', 'de',
#          'episodio', 'de', 'hematuria', 'macroscopica', 'se', 'realiza',
#          'cistoscopia', 'que', 'es', 'negativa', 'para', 'lesiones',
#          'malignas', 'pero', 'se', 'objetiva', 'estenosis', 'de', 'uretra'],
#         dtype='<U14'),
#   'spans': array([[558, 572],
#          [573, 580],
#          [581, 594],
#          [595, 600],
#          [601, 608],
#          [609, 621],
#          [622, 634],
#          [635, 646],
#          [648, 656],
#          [657, 659],
#          [660, 668],
#          [669, 677],
#          [678, 681],
#          [682, 691],
#          [692, 697],
#          [698, 706],
#          [707, 712],
#          [713, 715],
#          [716, 722],
#          [723, 734],
#          [735, 747],
#          [748, 756],
#          [757, 763],
#          [764, 770],
#          [771, 776],
#          [777, 779],
#          [780, 783],
#          [784, 787],
#          [788, 789],
#          [790, 794],
#          [795, 797],
#          [798, 806],
#          [807, 809],
#          [810, 819],
#          [820, 832],
#          [833, 835],
#          [836, 843],
#          [844, 855],
#          [856, 859],
#          [860, 862],
#          [863, 871],
#          [872, 876],
#          [877, 885],
#          [886, 894],
#          [895, 899],
#          [900, 902],
#          [903, 911],
#          [912, 921],
#          [922, 924],
#          [925, 931]]),
#   'lang': 'es'},
#  {'tokens': array(['se', 'intentan', 'dilataciones', 'progresivas', 'en', 'el',
#          'gabinete', 'de', 'urologia', 'sin', 'exito'], dtype='<U12'),
#   'spans': array([[ 934,  936],
#          [ 937,  945],
#          [ 946,  958],
#          [ 959,  970],
#          [ 971,  973],
#          [ 974,  976],
#          [ 977,  985],
#          [ 986,  988],
#          [ 989,  997],
#          [ 998, 1001],
#          [1002, 1007]]),
#   'lang': 'es'},
#  {'tokens': array(['se', 'solicita', 'estudio', 'de', 'imagen', 'que', 'confirma',
#          'la', 'existencia', 'de', 'estenosis', 'a', 'nivel', 'd', 'uretra',
#          'bulbar', 'por', 'lo', 'que', 'se', 'indica', 'uretrtomia',
#          'interna'], dtype='<U10'),
#   'spans': array([[1009, 1011],
#          [1012, 1020],
#          [1021, 1028],
#          [1029, 1031],
#          [1032, 1038],
#          [1039, 1042],
#          [1043, 1051],
#          [1052, 1054],
#          [1055, 1065],
#          [1066, 1068],
#          [1069, 1078],
#          [1079, 1080],
#          [1081, 1086],
#          [1087, 1088],
#          [1089, 1095],
#          [1096, 1102],
#          [1103, 1106],
#          [1107, 1109],
#          [1110, 1113],
#          [1114, 1116],
#          [1117, 1123],
#          [1124, 1134],
#          [1135, 1142]]),
#   'lang': 'es'},
#  {'tokens': array(['exploracio', 'complementaria', 'uretrocistografia', 'retrograda',
#          'cums', '112017', 'la', 'uretrografia', 'retrograda', 'muestra',
#          'una', 'uretra', 'anterior', 'con', 'dos', 'estenosis', 'focales',
#          'a', 'nivel', 'de', 'uretra', 'peneana', 'y', 'bulbar', 'aunque',
#          'se', 'observa', 'paso', 'de', 'contraste', 'retrogrado', 'a',
#          'vejiga'], dtype='<U17'),
#   'spans': array([[1144, 1154],
#          [1155, 1169],
#          [1170, 1187],
#          [1188, 1198],
#          [1201, 1205],
#          [1207, 1214],
#          [1217, 1219],
#          [1220, 1232],
#          [1233, 1243],
#          [1244, 1251],
#          [1252, 1255],
#          [1256, 1262],
#          [1263, 1271],
#          [1272, 1275],
#          [1276, 1279],
#          [1280, 1289],
#          [1290, 1297],
#          [1298, 1299],
#          [1300, 1305],
#          [1306, 1308],
#          [1309, 1315],
#          [1316, 1323],
#          [1324, 1325],
#          [1326, 1332],
#          [1334, 1340],
#          [1341, 1343],
#          [1344, 1351],
#          [1352, 1356],
#          [1357, 1359],
#          [1360, 1369],
#          [1370, 1380],
#          [1381, 1382],
#          [1383, 1389]]),
#   'lang': 'es'},
#  {'tokens': array(['vejiga', 'de', 'correcta', 'capacidad', '250', 'cc', 'de',
#          'contraste', 'de', 'paredes', 'trabeculadas', 'y', 'con',
#          'diverticulos', 'el', 'mayor', 'de', 'ellos', 'en', 'cara',
#          'posterolateral', 'izquierda', 'sin', 'observarse', 'defectos',
#          'de', 'replecion'], dtype='<U14'),
#   'spans': array([[1391, 1397],
#          [1398, 1400],
#          [1401, 1409],
#          [1410, 1419],
#          [1421, 1424],
#          [1425, 1427],
#          [1428, 1430],
#          [1431, 1440],
#          [1443, 1445],
#          [1446, 1453],
#          [1454, 1466],
#          [1467, 1468],
#          [1469, 1472],
#          [1473, 1485],
#          [1487, 1489],
#          [1490, 1495],
#          [1496, 1498],
#          [1499, 1504],
#          [1505, 1507],
#          [1508, 1512],
#          [1513, 1527],
#          [1528, 1537],
#          [1539, 1542],
#          [1543, 1553],
#          [1554, 1562],
#          [1563, 1565],
#          [1566, 1575]]),
#   'lang': 'es'},
#  {'tokens': array(['la', 'uretrografia', 'miccional', 'muestra', 'una', 'uretra',
#          'prostatica', 'dilatada', 'sin', 'claras', 'estenosis', 'focales',
#          'confirmandose', 'la', 'existencia', 'de', 'las', 'dos',
#          'estenosis', 'de', 'uretra', 'anterior', 'descritas',
#          'previamente'], dtype='<U13'),
#   'spans': array([[1577, 1579],
#          [1580, 1592],
#          [1593, 1602],
#          [1603, 1610],
#          [1611, 1614],
#          [1615, 1621],
#          [1622, 1632],
#          [1633, 1641],
#          [1643, 1646],
#          [1647, 1653],
#          [1654, 1663],
#          [1664, 1671],
#          [1672, 1685],
#          [1686, 1688],
#          [1689, 1699],
#          [1700, 1702],
#          [1703, 1706],
#          [1707, 1710],
#          [1711, 1720],
#          [1721, 1723],
#          [1724, 1730],
#          [1731, 1739],
#          [1740, 1749],
#          [1750, 1761]]),
#   'lang': 'es'},
#  {'tokens': array(['moderado', 'residuo', 'postmiccional', 'en', 'vejiga', 'asi',
#          'como', 'en', 'el', 'interior', 'del', 'diverticulo',
#          'posterolateral', 'izquierdo', 'descrito'], dtype='<U14'),
#   'spans': array([[1763, 1771],
#          [1772, 1779],
#          [1780, 1793],
#          [1794, 1796],
#          [1797, 1803],
#          [1804, 1807],
#          [1808, 1812],
#          [1813, 1815],
#          [1816, 1818],
#          [1819, 1827],
#          [1828, 1831],
#          [1832, 1843],
#          [1844, 1858],
#          [1859, 1868],
#          [1869, 1877]]),
#   'lang': 'es'},
#  {'tokens': array(['uretroscopia', '102017', 'falsa', 'via', 'a', 'nivel', 'de',
#          'uretra', 'peneana', 'siguiendo', 'la', 'uretra', 'se', 'detecta',
#          'gran', 'estenosis', 'que', 'no', 'permite', 'el', 'paso', 'de',
#          'una', 'guia'], dtype='<U12'),
#   'spans': array([[1879, 1891],
#          [1893, 1900],
#          [1902, 1907],
#          [1908, 1911],
#          [1912, 1913],
#          [1914, 1919],
#          [1920, 1922],
#          [1923, 1929],
#          [1930, 1937],
#          [1939, 1948],
#          [1949, 1951],
#          [1952, 1958],
#          [1959, 1961],
#          [1962, 1969],
#          [1970, 1974],
#          [1975, 1984],
#          [1985, 1988],
#          [1989, 1991],
#          [1992, 1999],
#          [2000, 2002],
#          [2003, 2007],
#          [2008, 2010],
#          [2011, 2014],
#          [2015, 2019]]),
#   'lang': 'es'},
#  {'tokens': array(['nhc', 'agevuro', '12', 'lopd', 'evolucio', 'clinica', 'el', '24',
#          'de', 'julio', 'de', '2018', 'con', 'el', 'consentimiento',
#          'informado', 'del', 'paciente', 'y', 'sin', 'contraindicacion',
#          'preoperatoria', 'se', 'realiza', 'uretrotomia', 'interna', 'sin',
#          'incidencias'], dtype='<U16'),
#   'spans': array([[2021, 2024],
#          [2047, 2056],
#          [2057, 2060],
#          [2061, 2065],
#          [2066, 2074],
#          [2075, 2082],
#          [2083, 2085],
#          [2086, 2088],
#          [2089, 2091],
#          [2092, 2097],
#          [2098, 2100],
#          [2101, 2105],
#          [2106, 2109],
#          [2110, 2112],
#          [2113, 2127],
#          [2128, 2137],
#          [2138, 2141],
#          [2142, 2150],
#          [2151, 2152],
#          [2153, 2156],
#          [2157, 2173],
#          [2174, 2187],
#          [2188, 2190],
#          [2191, 2198],
#          [2199, 2210],
#          [2211, 2218],
#          [2219, 2222],
#          [2223, 2234]]),
#   'lang': 'es'},
#  {'tokens': array(['tras', 'el', 'procedimiento', 'el', 'paciente', 'es',
#          'trasladado', 'a', 'la', 'planta', 'de', 'hospitalizacion',
#          'siendo', 'portador', 'de', 'lavado', 'vesical', 'continuo'],
#         dtype='<U15'),
#   'spans': array([[2236, 2240],
#          [2241, 2243],
#          [2244, 2257],
#          [2258, 2260],
#          [2261, 2269],
#          [2270, 2272],
#          [2273, 2283],
#          [2284, 2285],
#          [2286, 2288],
#          [2289, 2295],
#          [2296, 2298],
#          [2299, 2314],
#          [2315, 2321],
#          [2322, 2330],
#          [2331, 2333],
#          [2334, 2340],
#          [2341, 2348],
#          [2349, 2357]]),
#   'lang': 'es'},
#  {'tokens': array(['posteriormente', 'se', 'mantiene', 'en', 'buen', 'estado',
#          'general', 'afebril', 'hemodinamicamente', 'estable', 'y', 'con',
#          'buen', 'control', 'del', 'dolor'], dtype='<U17'),
#   'spans': array([[2359, 2373],
#          [2374, 2376],
#          [2377, 2385],
#          [2386, 2388],
#          [2389, 2393],
#          [2394, 2400],
#          [2401, 2408],
#          [2410, 2417],
#          [2419, 2436],
#          [2437, 2444],
#          [2445, 2446],
#          [2447, 2450],
#          [2451, 2455],
#          [2456, 2463],
#          [2464, 2467],
#          [2468, 2473]]),
#   'lang': 'es'},
#  {'tokens': array(['aclarado', 'progresivo', 'de', 'la', 'orina', 'con', 'los',
#          'lavados', 'vesicales', 'continuos', 'que', 'permiten', 'su',
#          'retirada', 'conserva', 'correcta', 'diuresis'], dtype='<U10'),
#   'spans': array([[2475, 2483],
#          [2484, 2494],
#          [2495, 2497],
#          [2498, 2500],
#          [2501, 2506],
#          [2507, 2510],
#          [2511, 2514],
#          [2515, 2522],
#          [2523, 2532],
#          [2533, 2542],
#          [2544, 2547],
#          [2548, 2556],
#          [2557, 2559],
#          [2560, 2568],
#          [2570, 2578],
#          [2579, 2587],
#          [2588, 2596]]),
#   'lang': 'es'},
#  {'tokens': array(['tolerancia', 'correcta', 'a', 'dieta', 'oral'], dtype='<U10'),
#   'spans': array([[2598, 2608],
#          [2609, 2617],
#          [2618, 2619],
#          [2620, 2625],
#          [2626, 2630]]),
#   'lang': 'es'},
#  {'tokens': array(['dada', 'la', 'buena', 'evolucion', 'se', 'decide', 'alta',
#          'domiciliaria', 'siendo', 'portador', 'de', 'sonda', 'vesical'],
#         dtype='<U12'),
#   'spans': array([[2632, 2636],
#          [2637, 2639],
#          [2640, 2645],
#          [2646, 2655],
#          [2656, 2658],
#          [2659, 2665],
#          [2666, 2670],
#          [2671, 2683],
#          [2684, 2690],
#          [2691, 2699],
#          [2700, 2702],
#          [2703, 2708],
#          [2709, 2716]]),
#   'lang': 'es'},
#  {'tokens': array(['orientacio', 'diagnostica', 'n400', 'hiperplasia', 'prostatica',
#          'benigna', 'sense', 'simptomes', 'en', 'les', 'vies', 'urinaries',
#          'inferiors', 'procediments', '0481', 'injeccio', 'en', 'el',
#          'nervi', 'periferic', 'd', 'anestesic', 'per', 'a', 'analgesia',
#          '580', 'uretrotomia'], dtype='<U12'),
#   'spans': array([[2718, 2728],
#          [2729, 2740],
#          [2741, 2746],
#          [2747, 2758],
#          [2759, 2769],
#          [2770, 2777],
#          [2778, 2783],
#          [2784, 2793],
#          [2794, 2796],
#          [2797, 2800],
#          [2801, 2805],
#          [2806, 2815],
#          [2816, 2825],
#          [2826, 2838],
#          [2839, 2844],
#          [2845, 2853],
#          [2854, 2856],
#          [2857, 2859],
#          [2860, 2865],
#          [2866, 2875],
#          [2876, 2878],
#          [2878, 2887],
#          [2888, 2891],
#          [2892, 2893],
#          [2894, 2903],
#          [2904, 2908],
#          [2909, 2920]]),
#   'lang': 'ca'},
#  {'tokens': array(['excisio', 'de', 'septe', 'uretral', 'uretrostomia', 'perineal',
#          'extraccio', 'de', 'calcul', 'uretral', 'per', 'incisio', 'sonda',
#          'vesical', 'profilaxis', 'antibiotica', 'antilucerosa', 'y',
#          'antitrombotica', 'tractament', 'i', 'recomanacions', 'a', 'lalta',
#          'abundante', 'ingesta', 'de', 'liquidos', 'entorno', 'a', 'dos',
#          'litros', 'y', 'medio', 'de', 'agua', 'al', 'dia'], dtype='<U14'),
#   'spans': array([[2922, 2929],
#          [2930, 2932],
#          [2933, 2938],
#          [2939, 2946],
#          [2948, 2960],
#          [2961, 2969],
#          [2971, 2980],
#          [2981, 2983],
#          [2984, 2990],
#          [2991, 2998],
#          [2999, 3002],
#          [3003, 3010],
#          [3011, 3016],
#          [3017, 3024],
#          [3025, 3035],
#          [3036, 3047],
#          [3049, 3061],
#          [3062, 3063],
#          [3064, 3078],
#          [3079, 3089],
#          [3090, 3091],
#          [3092, 3105],
#          [3106, 3107],
#          [3108, 3114],
#          [3115, 3125],
#          [3126, 3133],
#          [3134, 3136],
#          [3137, 3145],
#          [3146, 3153],
#          [3154, 3155],
#          [3156, 3159],
#          [3160, 3166],
#          [3167, 3168],
#          [3169, 3174],
#          [3175, 3177],
#          [3178, 3182],
#          [3183, 3185],
#          [3186, 3189]]),
#   'lang': 'es'},
#  {'tokens': array(['puede', 'orinar', 'con', 'restos', 'de', 'sangre', 'durante',
#          'las', 'proximas', 'semanas'], dtype='<U8'),
#   'spans': array([[3191, 3197],
#          [3198, 3204],
#          [3205, 3208],
#          [3209, 3215],
#          [3216, 3218],
#          [3219, 3225],
#          [3226, 3233],
#          [3234, 3237],
#          [3238, 3246],
#          [3247, 3254]]),
#   'lang': 'es'},
#  {'tokens': array(['es', 'normal', 'que', 'sienta', 'escozor', 'al', 'orinar', 'y',
#          'que', 'tenga', 'algun', 'escape', 'de', 'orina', 'y', 'urgencia',
#          'miccional', 'al', 'retirar', 'la', 'sonda', 'vesical'],
#         dtype='<U9'),
#   'spans': array([[3256, 3259],
#          [3260, 3266],
#          [3267, 3270],
#          [3271, 3277],
#          [3278, 3285],
#          [3286, 3288],
#          [3289, 3295],
#          [3296, 3297],
#          [3298, 3301],
#          [3302, 3307],
#          [3308, 3313],
#          [3314, 3320],
#          [3321, 3323],
#          [3324, 3329],
#          [3330, 3331],
#          [3332, 3340],
#          [3341, 3350],
#          [3351, 3353],
#          [3354, 3361],
#          [3362, 3364],
#          [3365, 3370],
#          [3371, 3378]]),
#   'lang': 'es'},
#  {'tokens': array(['mantener', 'sonda', 'vesical', 'durante', '14', 'dias', 'dos',
#          'semanas'], dtype='<U8'),
#   'spans': array([[3380, 3388],
#          [3389, 3394],
#          [3395, 3402],
#          [3403, 3410],
#          [3411, 3413],
#          [3414, 3418],
#          [3420, 3423],
#          [3424, 3431]]),
#   'lang': 'es'},
#  {'tokens': array(['ciprofloxacino', '500', 'mg', 'cada', '12h', 'durante', 'dos',
#          'semanas'], dtype='<U14'),
#   'spans': array([[3434, 3448],
#          [3449, 3452],
#          [3452, 3454],
#          [3455, 3459],
#          [3460, 3463],
#          [3464, 3471],
#          [3472, 3475],
#          [3476, 3483]]),
#   'lang': 'es'},
#  {'tokens': array(['paracetamol', '1', 'g', 'cada', '8', 'horas', 'si', 'molestias'],
#         dtype='<U11'),
#   'spans': array([[3485, 3497],
#          [3498, 3499],
#          [3500, 3501],
#          [3502, 3506],
#          [3507, 3508],
#          [3509, 3514],
#          [3515, 3517],
#          [3518, 3527]]),
#   'lang': 'es'},
#  {'tokens': array(['si', 'fiebre', 'mayor', 'de', '38c', 'empeoramiento', 'claro',
#          'del', 'estado', 'general', 'o', 'imposibilidad', 'miccional',
#          'por', 'obstruccion', 'de', 'sonda', 'vesical', 'o', 'despues',
#          'de', 'su', 'retirada', 'consultar', 'con', 'el', 'servicio', 'de',
#          'urgencias'], dtype='<U13'),
#   'spans': array([[3529, 3532],
#          [3533, 3539],
#          [3540, 3545],
#          [3546, 3548],
#          [3549, 3553],
#          [3555, 3568],
#          [3569, 3574],
#          [3575, 3578],
#          [3579, 3585],
#          [3586, 3593],
#          [3594, 3595],
#          [3596, 3609],
#          [3610, 3619],
#          [3620, 3623],
#          [3624, 3635],
#          [3636, 3638],
#          [3639, 3644],
#          [3645, 3652],
#          [3653, 3654],
#          [3655, 3662],
#          [3663, 3665],
#          [3666, 3668],
#          [3669, 3677],
#          [3679, 3688],
#          [3689, 3692],
#          [3693, 3695],
#          [3696, 3704],
#          [3705, 3707],
#          [3708, 3717]]),
#   'lang': 'es'},
#  {'tokens': array(['control', 'en', 'consultas', 'externas', 'de', 'urologia',
#          'segun', 'cita', 'en', 'hoja', 'adjunta'], dtype='<U9'),
#   'spans': array([[3719, 3727],
#          [3728, 3730],
#          [3731, 3740],
#          [3741, 3749],
#          [3750, 3752],
#          [3753, 3761],
#          [3762, 3767],
#          [3768, 3772],
#          [3773, 3775],
#          [3776, 3780],
#          [3781, 3788]]),
#   'lang': 'es'},
#  {'tokens': array(['destinacio', 'a', 'lalta', 'a', 'domicili', 'nhc', 'agevuro',
#          '22', 'lopd'], dtype='<U10'),
#   'spans': array([[3790, 3800],
#          [3801, 3802],
#          [3803, 3809],
#          [3811, 3812],
#          [3813, 3821],
#          [3822, 3825],
#          [3848, 3857],
#          [3858, 3861],
#          [3862, 3866]]),
#   'lang': 'es'}]

# %%
from spacy.tokenizer import Tokenizer
from copy import deepcopy

def custom_tokenizer(nlp):
    return Tokenizer(nlp.vocab, token_match=re.compile(r'\S+').match)

print("Preparing tokenizers...")
nlp_es_custom = deepcopy(nlp_es)
nlp_es_custom.tokenizer = custom_tokenizer(nlp_es_custom)
nlp_ca_custom = deepcopy(nlp_ca)
nlp_ca_custom.tokenizer = custom_tokenizer(nlp_ca_custom)
# Out:
# Preparing tokenizers...

# %%
# lemmatize
tokens_lemmatized = []
for d in tqdm(tokens):
	d_tokens = []
	for sent in d:
		lang = sent["lang"]
		# lemmatization works better with the whole sentence
		if lang == "es":
			doc = nlp_es_custom(" ".join(sent["tokens"]))
		else:
			doc = nlp_ca_custom(" ".join(sent["tokens"]))
		lemmas = [token.lemma_ for token in doc]
		assert len(lemmas) == len(sent["tokens"]), f"\n{lemmas}\n{sent['tokens']}"
		sent_tokens = {"tokens": np.array(lemmas), "spans": sent["spans"], "lang": lang}
		d_tokens.append(sent_tokens)
	tokens_lemmatized.append(d_tokens)
# Out:
# 100%|██████████| 254/254 [01:04<00:00,  3.95it/s]

# %%
tokens_lemmatized[0]
# Out:
# [{'tokens': array(['n', 'historia', 'clinic', 'nepisodi', 'sexe', 'home', 'datar',
#          'de', 'naixement', '16051936', 'edat', '82', 'any', 'procedencia',
#          'cex', 'mateix', 'hosp', 'servei', 'urologiar', 'data', 'de',
#          'ingres', '24072018', 'data', 'de', 'alt', '25072018', '085404',
#          'at', 'per', 'informe', 'de', 'alta', 'de', 'hospitalitzacio',
#          'motiu', 'de', 'ingres', 'paciente', 'que', 'ingresar', 'de',
#          'forma', 'programat', 'parar', 'realizacion', 'de', 'uretrotomia',
#          'intern'], dtype='<U15'),
#   'spans': array([[  1,   3],
#          [  4,  12],
#          [ 13,  20],
#          [ 33,  42],
#          [ 53,  57],
#          [ 59,  63],
#          [ 64,  68],
#          [ 69,  71],
#          [ 72,  81],
#          [ 83,  93],
#          [ 94,  98],
#          [100, 102],
#          [103, 107],
#          [108, 119],
#          [120, 123],
#          [124, 130],
#          [131, 135],
#          [136, 142],
#          [143, 151],
#          [152, 156],
#          [157, 159],
#          [159, 165],
#          [166, 176],
#          [177, 181],
#          [182, 184],
#          [184, 188],
#          [189, 199],
#          [200, 208],
#          [209, 213],
#          [214, 217],
#          [267, 274],
#          [275, 277],
#          [277, 281],
#          [282, 284],
#          [284, 299],
#          [300, 305],
#          [306, 308],
#          [308, 314],
#          [315, 323],
#          [324, 327],
#          [328, 335],
#          [336, 338],
#          [339, 344],
#          [345, 355],
#          [356, 360],
#          [361, 372],
#          [373, 375],
#          [376, 387],
#          [388, 395]]),
#   'lang': 'ca'},
#  {'tokens': array(['antecedent', 'alergiar', 'a', 'penicilina', 'y', 'cloramfenicol'],
#         dtype='<U13'),
#   'spans': array([[398, 409],
#          [410, 417],
#          [418, 419],
#          [420, 430],
#          [431, 432],
#          [433, 446]]),
#   'lang': 'ca'},
#  {'tokens': array(['no', 'habito', 'toxico'], dtype='<U6'),
#   'spans': array([[449, 451],
#          [452, 459],
#          [460, 467]]),
#   'lang': 'es'},
#  {'tokens': array(['antecedente', 'medico', 'bloqueo', 'auriculoventricular', 'de',
#          'primero', 'grado', 'hipertension', 'arterial'], dtype='<U19'),
#   'spans': array([[469, 481],
#          [482, 489],
#          [491, 498],
#          [499, 518],
#          [519, 521],
#          [522, 528],
#          [529, 534],
#          [535, 547],
#          [548, 556]]),
#   'lang': 'es'},
#  {'tokens': array(['diverticulosis', 'extenso', 'insuficiencia', 'renal', 'cronico',
#          'colelitiasis', 'antecedente', 'quirurgico', 'exeresis', 'de',
#          'lesión', 'cutanea', 'con', 'anestesia', 'local', 'protesis',
#          'total', 'de', 'cadera', 'cordectomia', 'herniorrafia', 'inguinal',
#          'proz', 'actual', 'var', 'de', '81a', 'que', 'a', 'raiz', 'de',
#          'episodio', 'de', 'hematuria', 'macroscopico', 'él', 'realizar',
#          'cistoscopia', 'que', 'ser', 'negativo', 'para', 'lesión',
#          'maligno', 'pero', 'él', 'objetiir', 'estenosis', 'de', 'uretro'],
#         dtype='<U14'),
#   'spans': array([[558, 572],
#          [573, 580],
#          [581, 594],
#          [595, 600],
#          [601, 608],
#          [609, 621],
#          [622, 634],
#          [635, 646],
#          [648, 656],
#          [657, 659],
#          [660, 668],
#          [669, 677],
#          [678, 681],
#          [682, 691],
#          [692, 697],
#          [698, 706],
#          [707, 712],
#          [713, 715],
#          [716, 722],
#          [723, 734],
#          [735, 747],
#          [748, 756],
#          [757, 763],
#          [764, 770],
#          [771, 776],
#          [777, 779],
#          [780, 783],
#          [784, 787],
#          [788, 789],
#          [790, 794],
#          [795, 797],
#          [798, 806],
#          [807, 809],
#          [810, 819],
#          [820, 832],
#          [833, 835],
#          [836, 843],
#          [844, 855],
#          [856, 859],
#          [860, 862],
#          [863, 871],
#          [872, 876],
#          [877, 885],
#          [886, 894],
#          [895, 899],
#          [900, 902],
#          [903, 911],
#          [912, 921],
#          [922, 924],
#          [925, 931]]),
#   'lang': 'es'},
#  {'tokens': array(['él', 'intentar', 'dilatación', 'progresivo', 'en', 'el',
#          'gabinete', 'de', 'urologia', 'sin', 'exito'], dtype='<U10'),
#   'spans': array([[ 934,  936],
#          [ 937,  945],
#          [ 946,  958],
#          [ 959,  970],
#          [ 971,  973],
#          [ 974,  976],
#          [ 977,  985],
#          [ 986,  988],
#          [ 989,  997],
#          [ 998, 1001],
#          [1002, 1007]]),
#   'lang': 'es'},
#  {'tokens': array(['él', 'solicitar', 'estudio', 'de', 'imagen', 'que', 'confirmar',
#          'el', 'existencia', 'de', 'estenosis', 'a', 'nivel', 'd', 'uretro',
#          'bulbar', 'por', 'él', 'que', 'él', 'indicar', 'uretrtomia',
#          'interno'], dtype='<U10'),
#   'spans': array([[1009, 1011],
#          [1012, 1020],
#          [1021, 1028],
#          [1029, 1031],
#          [1032, 1038],
#          [1039, 1042],
#          [1043, 1051],
#          [1052, 1054],
#          [1055, 1065],
#          [1066, 1068],
#          [1069, 1078],
#          [1079, 1080],
#          [1081, 1086],
#          [1087, 1088],
#          [1089, 1095],
#          [1096, 1102],
#          [1103, 1106],
#          [1107, 1109],
#          [1110, 1113],
#          [1114, 1116],
#          [1117, 1123],
#          [1124, 1134],
#          [1135, 1142]]),
#   'lang': 'es'},
#  {'tokens': array(['exploracio', 'complementario', 'uretrocistografia', 'retrogrado',
#          'cums', '112017', 'el', 'uretrografia', 'retrogrado', 'mostrar',
#          'uno', 'uretra', 'anterior', 'con', 'dos', 'estenosis', 'focal',
#          'a', 'nivel', 'de', 'uretra', 'peneán', 'y', 'bulbar', 'aunque',
#          'él', 'observar', 'paso', 'de', 'contraste', 'retrogrado', 'a',
#          'vejiga'], dtype='<U17'),
#   'spans': array([[1144, 1154],
#          [1155, 1169],
#          [1170, 1187],
#          [1188, 1198],
#          [1201, 1205],
#          [1207, 1214],
#          [1217, 1219],
#          [1220, 1232],
#          [1233, 1243],
#          [1244, 1251],
#          [1252, 1255],
#          [1256, 1262],
#          [1263, 1271],
#          [1272, 1275],
#          [1276, 1279],
#          [1280, 1289],
#          [1290, 1297],
#          [1298, 1299],
#          [1300, 1305],
#          [1306, 1308],
#          [1309, 1315],
#          [1316, 1323],
#          [1324, 1325],
#          [1326, 1332],
#          [1334, 1340],
#          [1341, 1343],
#          [1344, 1351],
#          [1352, 1356],
#          [1357, 1359],
#          [1360, 1369],
#          [1370, 1380],
#          [1381, 1382],
#          [1383, 1389]]),
#   'lang': 'es'},
#  {'tokens': array(['vejiga', 'de', 'correcto', 'capacidad', '250', 'cc', 'de',
#          'contraste', 'de', 'pared', 'trabeculada', 'y', 'con',
#          'diverticulo', 'el', 'mayor', 'de', 'él', 'en', 'cara',
#          'posterolateral', 'izquierdo', 'sin', 'observar él', 'defecto',
#          'de', 'replecion'], dtype='<U14'),
#   'spans': array([[1391, 1397],
#          [1398, 1400],
#          [1401, 1409],
#          [1410, 1419],
#          [1421, 1424],
#          [1425, 1427],
#          [1428, 1430],
#          [1431, 1440],
#          [1443, 1445],
#          [1446, 1453],
#          [1454, 1466],
#          [1467, 1468],
#          [1469, 1472],
#          [1473, 1485],
#          [1487, 1489],
#          [1490, 1495],
#          [1496, 1498],
#          [1499, 1504],
#          [1505, 1507],
#          [1508, 1512],
#          [1513, 1527],
#          [1528, 1537],
#          [1539, 1542],
#          [1543, 1553],
#          [1554, 1562],
#          [1563, 1565],
#          [1566, 1575]]),
#   'lang': 'es'},
#  {'tokens': array(['el', 'uretrografia', 'miccional', 'mostrar', 'uno', 'uretro',
#          'prostatica', 'dilatado', 'sin', 'claro', 'estenosis', 'focal',
#          'confirmar él', 'el', 'existencia', 'de', 'el', 'dos', 'estenosis',
#          'de', 'uretra', 'anterior', 'descrita', 'previamente'],
#         dtype='<U12'),
#   'spans': array([[1577, 1579],
#          [1580, 1592],
#          [1593, 1602],
#          [1603, 1610],
#          [1611, 1614],
#          [1615, 1621],
#          [1622, 1632],
#          [1633, 1641],
#          [1643, 1646],
#          [1647, 1653],
#          [1654, 1663],
#          [1664, 1671],
#          [1672, 1685],
#          [1686, 1688],
#          [1689, 1699],
#          [1700, 1702],
#          [1703, 1706],
#          [1707, 1710],
#          [1711, 1720],
#          [1721, 1723],
#          [1724, 1730],
#          [1731, 1739],
#          [1740, 1749],
#          [1750, 1761]]),
#   'lang': 'es'},
#  {'tokens': array(['moderado', 'residuo', 'postmiccional', 'en', 'vejiga', 'asi',
#          'como', 'en', 'el', 'interior', 'del', 'diverticulo',
#          'posterolateral', 'izquierdo', 'descrito'], dtype='<U14'),
#   'spans': array([[1763, 1771],
#          [1772, 1779],
#          [1780, 1793],
#          [1794, 1796],
#          [1797, 1803],
#          [1804, 1807],
#          [1808, 1812],
#          [1813, 1815],
#          [1816, 1818],
#          [1819, 1827],
#          [1828, 1831],
#          [1832, 1843],
#          [1844, 1858],
#          [1859, 1868],
#          [1869, 1877]]),
#   'lang': 'es'},
#  {'tokens': array(['uretroscopia', '102017', 'falso', 'via', 'a', 'nivel', 'de',
#          'uretra', 'peneán', 'seguir', 'el', 'uretro', 'él', 'detectar',
#          'gran', 'estenosis', 'que', 'no', 'permitir', 'el', 'paso', 'de',
#          'uno', 'guia'], dtype='<U12'),
#   'spans': array([[1879, 1891],
#          [1893, 1900],
#          [1902, 1907],
#          [1908, 1911],
#          [1912, 1913],
#          [1914, 1919],
#          [1920, 1922],
#          [1923, 1929],
#          [1930, 1937],
#          [1939, 1948],
#          [1949, 1951],
#          [1952, 1958],
#          [1959, 1961],
#          [1962, 1969],
#          [1970, 1974],
#          [1975, 1984],
#          [1985, 1988],
#          [1989, 1991],
#          [1992, 1999],
#          [2000, 2002],
#          [2003, 2007],
#          [2008, 2010],
#          [2011, 2014],
#          [2015, 2019]]),
#   'lang': 'es'},
#  {'tokens': array(['nhc', 'agevuro', '12', 'lopd', 'evolucio', 'clinico', 'el', '24',
#          'de', 'julio', 'de', '2018', 'con', 'el', 'consentimiento',
#          'informado', 'del', 'paciente', 'y', 'sin', 'contraindicacion',
#          'preoperatorio', 'él', 'realizar', 'uretrotomia', 'interno', 'sin',
#          'incidencia'], dtype='<U16'),
#   'spans': array([[2021, 2024],
#          [2047, 2056],
#          [2057, 2060],
#          [2061, 2065],
#          [2066, 2074],
#          [2075, 2082],
#          [2083, 2085],
#          [2086, 2088],
#          [2089, 2091],
#          [2092, 2097],
#          [2098, 2100],
#          [2101, 2105],
#          [2106, 2109],
#          [2110, 2112],
#          [2113, 2127],
#          [2128, 2137],
#          [2138, 2141],
#          [2142, 2150],
#          [2151, 2152],
#          [2153, 2156],
#          [2157, 2173],
#          [2174, 2187],
#          [2188, 2190],
#          [2191, 2198],
#          [2199, 2210],
#          [2211, 2218],
#          [2219, 2222],
#          [2223, 2234]]),
#   'lang': 'es'},
#  {'tokens': array(['tras', 'el', 'procedimiento', 'el', 'paciente', 'ser',
#          'trasladar', 'a', 'el', 'planta', 'de', 'hospitalizacion', 'ser',
#          'portador', 'de', 'lavado', 'vesical', 'continuo'], dtype='<U15'),
#   'spans': array([[2236, 2240],
#          [2241, 2243],
#          [2244, 2257],
#          [2258, 2260],
#          [2261, 2269],
#          [2270, 2272],
#          [2273, 2283],
#          [2284, 2285],
#          [2286, 2288],
#          [2289, 2295],
#          [2296, 2298],
#          [2299, 2314],
#          [2315, 2321],
#          [2322, 2330],
#          [2331, 2333],
#          [2334, 2340],
#          [2341, 2348],
#          [2349, 2357]]),
#   'lang': 'es'},
#  {'tokens': array(['posteriormente', 'él', 'mantener', 'en', 'buen', 'estado',
#          'general', 'afebril', 'hemodinamicamente', 'estable', 'y', 'con',
#          'buen', 'control', 'del', 'dolor'], dtype='<U17'),
#   'spans': array([[2359, 2373],
#          [2374, 2376],
#          [2377, 2385],
#          [2386, 2388],
#          [2389, 2393],
#          [2394, 2400],
#          [2401, 2408],
#          [2410, 2417],
#          [2419, 2436],
#          [2437, 2444],
#          [2445, 2446],
#          [2447, 2450],
#          [2451, 2455],
#          [2456, 2463],
#          [2464, 2467],
#          [2468, 2473]]),
#   'lang': 'es'},
#  {'tokens': array(['aclarado', 'progresivo', 'de', 'el', 'orina', 'con', 'el',
#          'lavado', 'vesical', 'continuo', 'que', 'permitir', 'su',
#          'retirada', 'conservar', 'correcto', 'diuresis'], dtype='<U10'),
#   'spans': array([[2475, 2483],
#          [2484, 2494],
#          [2495, 2497],
#          [2498, 2500],
#          [2501, 2506],
#          [2507, 2510],
#          [2511, 2514],
#          [2515, 2522],
#          [2523, 2532],
#          [2533, 2542],
#          [2544, 2547],
#          [2548, 2556],
#          [2557, 2559],
#          [2560, 2568],
#          [2570, 2578],
#          [2579, 2587],
#          [2588, 2596]]),
#   'lang': 'es'},
#  {'tokens': array(['tolerancia', 'correcto', 'a', 'dieta', 'oral'], dtype='<U10'),
#   'spans': array([[2598, 2608],
#          [2609, 2617],
#          [2618, 2619],
#          [2620, 2625],
#          [2626, 2630]]),
#   'lang': 'es'},
#  {'tokens': array(['dar', 'el', 'buen', 'evolucion', 'él', 'decidir', 'alto',
#          'domiciliario', 'ser', 'portador', 'de', 'sonda', 'vesical'],
#         dtype='<U12'),
#   'spans': array([[2632, 2636],
#          [2637, 2639],
#          [2640, 2645],
#          [2646, 2655],
#          [2656, 2658],
#          [2659, 2665],
#          [2666, 2670],
#          [2671, 2683],
#          [2684, 2690],
#          [2691, 2699],
#          [2700, 2702],
#          [2703, 2708],
#          [2709, 2716]]),
#   'lang': 'es'},
#  {'tokens': array(['orientacio', 'diagnosticar', 'n400', 'hiperplasia', 'prostatic',
#          'benigna', 'sense', 'simptoma', 'en', 'el', 'via', 'urinari',
#          'inferior', 'procediment', '0481', 'injecciar', 'en', 'el',
#          'nervi', 'periferic', 'de', 'anestesic', 'per', 'a', 'analgesia',
#          '580', 'uretrotomia'], dtype='<U12'),
#   'spans': array([[2718, 2728],
#          [2729, 2740],
#          [2741, 2746],
#          [2747, 2758],
#          [2759, 2769],
#          [2770, 2777],
#          [2778, 2783],
#          [2784, 2793],
#          [2794, 2796],
#          [2797, 2800],
#          [2801, 2805],
#          [2806, 2815],
#          [2816, 2825],
#          [2826, 2838],
#          [2839, 2844],
#          [2845, 2853],
#          [2854, 2856],
#          [2857, 2859],
#          [2860, 2865],
#          [2866, 2875],
#          [2876, 2878],
#          [2878, 2887],
#          [2888, 2891],
#          [2892, 2893],
#          [2894, 2903],
#          [2904, 2908],
#          [2909, 2920]]),
#   'lang': 'ca'},
#  {'tokens': array(['excisio', 'de', 'septe', 'uretral', 'uretrostomia', 'perineal',
#          'extraccio', 'de', 'calcul', 'uretral', 'per', 'incisio', 'sonda',
#          'vesical', 'profilaxis', 'antibiotico', 'antilucerós', 'y',
#          'antitrombotico', 'tractament', 'i', 'recomanacions', 'a', 'lalta',
#          'abundante', 'ingesta', 'de', 'liquido', 'entorno', 'a', 'dos',
#          'litro', 'y', 'medio', 'de', 'agua', 'al', 'dia'], dtype='<U14'),
#   'spans': array([[2922, 2929],
#          [2930, 2932],
#          [2933, 2938],
#          [2939, 2946],
#          [2948, 2960],
#          [2961, 2969],
#          [2971, 2980],
#          [2981, 2983],
#          [2984, 2990],
#          [2991, 2998],
#          [2999, 3002],
#          [3003, 3010],
#          [3011, 3016],
#          [3017, 3024],
#          [3025, 3035],
#          [3036, 3047],
#          [3049, 3061],
#          [3062, 3063],
#          [3064, 3078],
#          [3079, 3089],
#          [3090, 3091],
#          [3092, 3105],
#          [3106, 3107],
#          [3108, 3114],
#          [3115, 3125],
#          [3126, 3133],
#          [3134, 3136],
#          [3137, 3145],
#          [3146, 3153],
#          [3154, 3155],
#          [3156, 3159],
#          [3160, 3166],
#          [3167, 3168],
#          [3169, 3174],
#          [3175, 3177],
#          [3178, 3182],
#          [3183, 3185],
#          [3186, 3189]]),
#   'lang': 'es'},
#  {'tokens': array(['poder', 'orinar', 'con', 'resto', 'de', 'sangre', 'durante', 'el',
#          'proxima', 'semana'], dtype='<U7'),
#   'spans': array([[3191, 3197],
#          [3198, 3204],
#          [3205, 3208],
#          [3209, 3215],
#          [3216, 3218],
#          [3219, 3225],
#          [3226, 3233],
#          [3234, 3237],
#          [3238, 3246],
#          [3247, 3254]]),
#   'lang': 'es'},
#  {'tokens': array(['ser', 'normal', 'que', 'sentar', 'escozor', 'al', 'orinar', 'y',
#          'que', 'tener', 'algun', 'escape', 'de', 'orina', 'y', 'urgencia',
#          'miccional', 'al', 'retirar', 'el', 'sonda', 'vesical'],
#         dtype='<U9'),
#   'spans': array([[3256, 3259],
#          [3260, 3266],
#          [3267, 3270],
#          [3271, 3277],
#          [3278, 3285],
#          [3286, 3288],
#          [3289, 3295],
#          [3296, 3297],
#          [3298, 3301],
#          [3302, 3307],
#          [3308, 3313],
#          [3314, 3320],
#          [3321, 3323],
#          [3324, 3329],
#          [3330, 3331],
#          [3332, 3340],
#          [3341, 3350],
#          [3351, 3353],
#          [3354, 3361],
#          [3362, 3364],
#          [3365, 3370],
#          [3371, 3378]]),
#   'lang': 'es'},
#  {'tokens': array(['mantener', 'sonda', 'vesical', 'durante', '14', 'dia', 'dos',
#          'semana'], dtype='<U8'),
#   'spans': array([[3380, 3388],
#          [3389, 3394],
#          [3395, 3402],
#          [3403, 3410],
#          [3411, 3413],
#          [3414, 3418],
#          [3420, 3423],
#          [3424, 3431]]),
#   'lang': 'es'},
#  {'tokens': array(['ciprofloxacino', '500', 'mg', 'cada', '12h', 'durante', 'dos',
#          'semana'], dtype='<U14'),
#   'spans': array([[3434, 3448],
#          [3449, 3452],
#          [3452, 3454],
#          [3455, 3459],
#          [3460, 3463],
#          [3464, 3471],
#          [3472, 3475],
#          [3476, 3483]]),
#   'lang': 'es'},
#  {'tokens': array(['paracetamol', '1', 'g', 'cada', '8', 'hora', 'si', 'molestia'],
#         dtype='<U11'),
#   'spans': array([[3485, 3497],
#          [3498, 3499],
#          [3500, 3501],
#          [3502, 3506],
#          [3507, 3508],
#          [3509, 3514],
#          [3515, 3517],
#          [3518, 3527]]),
#   'lang': 'es'},
#  {'tokens': array(['si', 'fiebre', 'mayor', 'de', '38c', 'empeoramiento', 'claro',
#          'del', 'estado', 'general', 'o', 'imposibilidad', 'miccional',
#          'por', 'obstruccion', 'de', 'sonda', 'vesical', 'o', 'despu', 'de',
#          'su', 'retirada', 'consultar', 'con', 'el', 'servicio', 'de',
#          'urgencia'], dtype='<U13'),
#   'spans': array([[3529, 3532],
#          [3533, 3539],
#          [3540, 3545],
#          [3546, 3548],
#          [3549, 3553],
#          [3555, 3568],
#          [3569, 3574],
#          [3575, 3578],
#          [3579, 3585],
#          [3586, 3593],
#          [3594, 3595],
#          [3596, 3609],
#          [3610, 3619],
#          [3620, 3623],
#          [3624, 3635],
#          [3636, 3638],
#          [3639, 3644],
#          [3645, 3652],
#          [3653, 3654],
#          [3655, 3662],
#          [3663, 3665],
#          [3666, 3668],
#          [3669, 3677],
#          [3679, 3688],
#          [3689, 3692],
#          [3693, 3695],
#          [3696, 3704],
#          [3705, 3707],
#          [3708, 3717]]),
#   'lang': 'es'},
#  {'tokens': array(['control', 'en', 'consulta', 'externo', 'de', 'urologia', 'segun',
#          'cita', 'en', 'hoja', 'adjunto'], dtype='<U8'),
#   'spans': array([[3719, 3727],
#          [3728, 3730],
#          [3731, 3740],
#          [3741, 3749],
#          [3750, 3752],
#          [3753, 3761],
#          [3762, 3767],
#          [3768, 3772],
#          [3773, 3775],
#          [3776, 3780],
#          [3781, 3788]]),
#   'lang': 'es'},
#  {'tokens': array(['destinacio', 'a', 'lalta', 'a', 'domicili', 'nhc', 'agevuro',
#          '22', 'lopd'], dtype='<U10'),
#   'spans': array([[3790, 3800],
#          [3801, 3802],
#          [3803, 3809],
#          [3811, 3812],
#          [3813, 3821],
#          [3822, 3825],
#          [3848, 3857],
#          [3858, 3861],
#          [3862, 3866]]),
#   'lang': 'es'}]

# %%
def save_tokens(tokens, path):
	tokens = [
		{
			"tokens": sent["tokens"].tolist(),
			"spans": sent["spans"].tolist(),
			"lang": sent["lang"]
		}
		for d in tokens for sent in d
	]
	with open(path, 'w') as f:
		json.dump(tokens, f)

save_tokens(tokens_lemmatized, os.path.join(ROOT_DIR, "data", "training_data_tokens.json"))

# %%
def load_tokens(path):
	with open(path, 'r') as f:
		tokens = json.load(f)
	tokens = [
		{
			"tokens": np.array(sent["tokens"]),
			"spans": np.array(sent["spans"]),
			"lang": sent["lang"]
		}
		for sent in tokens
	]
	return tokens

tokens_lemmatized = load_tokens(os.path.join(ROOT_DIR, "data", "training_data_tokens.json"))
